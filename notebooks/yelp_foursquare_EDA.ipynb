# %%
# imports

# %% [markdown]
# # Foursquare

# %% [markdown]
# Send a request to Foursquare with a small radius (1000m) for all the bike stations in your city of choice.

# %%
# Import necessary Libraries

import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation


# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

#!pip install folium
import folium # plotting library

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import json 

from pandas.io.json import json_normalize 

import matplotlib.cm as cm
import matplotlib.colors as colors

from sklearn.cluster import KMeans

from urllib.request import urlopen
from bs4 import BeautifulSoup

from IPython.display import JSON 
import citybikes

print('Folium installed')
print('Libraries imported.')
# Out:
# Folium installed
# Libraries imported.

# %%
Stations = pd.read_csv("B:/Week3/Project2/NYC_stations.csv")
df_NYC_stations = pd.DataFrame(Stations, columns = ['name', 'longitude', 'latitude', 'free_bikes', 'empty_slots', 'extra/ebikes', 'extra/has_ebikes', 'extra/last_updated', 'extra/payment/0', 'extra/payment/1', 'extra/payment-terminal', 'extra/renting', 'extra/returning', 'extra/slots', 'extra/uid', 'id', 'timestamp' ])
df_NYC_stations.head()
# Out:
#                                  name  longitude   latitude  free_bikes  \
# 0            W 100 St & Manhattan Ave -73.964500  40.795000          17
# 1          7 Ave & Central Park South -73.979069  40.766741           0
# 2             Bedford Ave & Bergen St -73.952918  40.676368           9
# 3                      28 St & 41 Ave -73.937970  40.751047           0
# 4  Frederick Douglass Blvd & W 112 St -73.957145  40.801694          21
#
#    empty_slots  extra/ebikes  extra/has_ebikes  extra/last_updated  \
# 0           17             4              True          1682399328
# 1           71             0              True          1682399257
# 2           13             3              True          1682399292
# 3           19             0              True          1682399333
# 4            9             0              True          1682399241
#
#   extra/payment/0 extra/payment/1  extra/payment-terminal  extra/renting  \
# ...

# %%
# From part 1, the information of NEW YORK CITY IN US
{'company': ['NYC Bike Share, LLC', 'Motivate International, Inc.', 'PBSC Urban Solutions'], 'ebikes': True, 'gbfs_href': 'https://gbfs.citibikenyc.com/gbfs/gbfs.json', 'href': '/v2/networks/citi-bike-nyc', 'id': 'citi-bike-nyc', 'location': {'city': 'New York, NY', 'country': 'US', 'latitude': 40.7143528, 'longitude': -74.00597309999999}, 'name': 'Citi Bike'}
# Out:
# {'company': ['NYC Bike Share, LLC',
#   'Motivate International, Inc.',
#   'PBSC Urban Solutions'],
#  'ebikes': True,
#  'gbfs_href': 'https://gbfs.citibikenyc.com/gbfs/gbfs.json',
#  'href': '/v2/networks/citi-bike-nyc',
#  'id': 'citi-bike-nyc',
#  'location': {'city': 'New York, NY',
#   'country': 'US',
#   'latitude': 40.7143528,
#   'longitude': -74.00597309999999},
#  'name': 'Citi Bike'}

# %%
# NEW YORK CITY IN US
latitude = 40.7143528
longitude = -74.00597309999999
DISTANCE = 1000

# %%
import requests

url = "https://api.foursquare.com/v3/places/search"

params = {
  	"query": "stations",
  	"ll": "40.7143528,-74.00597309999999",
  	"open_now": "true",
  	"sort":"DISTANCE"
}

headers = {
    "Accept": "application/json",
    "Authorization": "fsq3QCMQzu5q7wo8h8uX8hioXm5u+3pL1NG21qFYiX7zyT8="
}

response = requests.request("GET", url, params=params, headers=headers)

print(response.text)
# Out:
# {"results":[{"fsq_id":"4aaa4e0ef964a520ad5520e3","categories":[{"id":19046,"name":"Metro Station","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/travel/subway_","suffix":".png"}}],"chains":[],"distance":224,"geocodes":{"drop_off":{"latitude":40.71243,"longitude":-74.004923},"main":{"latitude":40.712558,"longitude":-74.004995}},"link":"/v3/places/4aaa4e0ef964a520ad5520e3","location":{"address":"Centre St","census_block":"360610031002008","country":"US","cross_street":"Chambers St","dma":"New York","formatted_address":"Centre St (Chambers St), New York, NY 10007","locality":"New York","postcode":"10007","region":"NY"},"name":"MTA Subway - Brooklyn Bridge/City Hall/Chambers St","related_places":{"children":[]},"timezone":"America/New_York"},{"fsq_id":"4b78360df964a520a7bc2ee3","categories":[{"id":19000,"name":"Travel and Transportation","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/travel/default_","suffix":".png"}}],"chains":[],"distance":308,"geocodes":{"main":{"l
# ...

# %% [markdown]
# Parse through the response to get the POI (such as restaurants, bars, etc) details you want (ratings, name, location, etc)

# %%
import requests

url = "https://api.foursquare.com/v3/places/search"

params = {
  	"query": "Italian returants",
  	"ll": "40.7143528,-74.00597309999999",
  	"open_now": "true",
  	"sort":"DISTANCE"
}

headers = {
    "Accept": "application/json",
    "Authorization": "fsq3QCMQzu5q7wo8h8uX8hioXm5u+3pL1NG21qFYiX7zyT8="
}

response = requests.request("GET", url, params=params, headers=headers)

print(response.text)
# Out:
# {"results":[{"fsq_id":"528bf16711d2b7722da6b51c","categories":[{"id":13002,"name":"Bakery","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/bakery_","suffix":".png"}},{"id":13035,"name":"Coffee Shop","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_","suffix":".png"}},{"id":13334,"name":"Sandwich Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/deli_","suffix":".png"}}],"chains":[],"distance":444,"geocodes":{"drop_off":{"latitude":40.710445,"longitude":-74.007517},"main":{"latitude":40.710597,"longitude":-74.007667},"roof":{"latitude":40.710597,"longitude":-74.007667}},"link":"/v3/places/528bf16711d2b7722da6b51c","location":{"address":"97 Nassau St","census_block":"360610015011017","country":"US","cross_street":"at Ann St","dma":"New York","formatted_address":"97 Nassau St (at Ann St), New York, NY 10038","locality":"New York","postcode":"10038","region":"NY"},"name":"Pisillo Italian Cafe","related_places":{},"timezone":"A
# ...

# %%
import requests

url = "https://api.foursquare.com/v3/places/search"

params = {
  	"query": "bars",
  	"ll": "40.7143528,-74.00597309999999",
  	"open_now": "true",
  	"sort":"DISTANCE"
}

headers = {
    "Accept": "application/json",
    "Authorization": "fsq3QCMQzu5q7wo8h8uX8hioXm5u+3pL1NG21qFYiX7zyT8="
}

response = requests.request("GET", url, params=params, headers=headers)

print(response.text)
# Out:
# {"results":[{"fsq_id":"5a318ad0bd897e22be2aa60d","categories":[{"id":13065,"name":"Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/default_","suffix":".png"}}],"chains":[],"distance":312,"geocodes":{"drop_off":{"latitude":40.714244,"longitude":-74.00982},"main":{"latitude":40.714424,"longitude":-74.009739},"roof":{"latitude":40.714424,"longitude":-74.009739}},"link":"/v3/places/5a318ad0bd897e22be2aa60d","location":{"address":"57 Murray St","census_block":"360610021001006","country":"US","cross_street":"","dma":"New York","formatted_address":"57 Murray St, New York, NY 10007","locality":"New York","postcode":"10007","region":"NY"},"name":"Monk McGinn's","related_places":{},"timezone":"America/New_York"},{"fsq_id":"3fd66200f964a52083e61ee3","categories":[{"id":13065,"name":"Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/default_","suffix":".png"}}],"chains":[],"distance":342,"geocodes":{"main":{"latitude":40.716902,"longitude":-74.00
# ...

# %%
import requests

url = "https://api.foursquare.com/v3/places/search"

params = {
  	"query": "coffee",
  	"ll": "40.7143528,-74.00597309999999",
  	"open_now": "true",
  	"sort":"DISTANCE"
}

headers = {
    "Accept": "application/json",
    "Authorization": "fsq3QCMQzu5q7wo8h8uX8hioXm5u+3pL1NG21qFYiX7zyT8="
}

response = requests.request("GET", url, params=params, headers=headers)

print(response.text)
# Out:
# {"results":[{"fsq_id":"4c154c9a77cea593c401d260","categories":[{"id":13002,"name":"Bakery","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/bakery_","suffix":".png"}},{"id":13145,"name":"Fast Food Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/fastfood_","suffix":".png"}},{"id":13263,"name":"Japanese Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/japanese_","suffix":".png"}}],"chains":[],"distance":250,"geocodes":{"main":{"latitude":40.713863,"longitude":-74.008538},"roof":{"latitude":40.713863,"longitude":-74.008538}},"link":"/v3/places/4c154c9a77cea593c401d260","location":{"address":"25 Murray St","address_extended":"Frnt 1","census_block":"360610021001005","country":"US","cross_street":"at Church St","dma":"New York","formatted_address":"25 Murray St (at Church St), New York, NY 10007","locality":"New York","postcode":"10007","region":"NY"},"name":"Takahachi Bakery","related_places":{},"timezone":"America/New_York"
# ...

# %%
import requests

url = "https://api.foursquare.com/v3/places/search"

params = {
  	"query": "schools",
  	"ll": "40.7143528,-74.00597309999999",
  	"open_now": "true",
  	"sort":"DISTANCE"
}

headers = {
    "Accept": "application/json",
    "Authorization": "fsq3QCMQzu5q7wo8h8uX8hioXm5u+3pL1NG21qFYiX7zyT8="
}

response = requests.request("GET", url, params=params, headers=headers)

print(response.text)
# Out:
# {"results":[{"fsq_id":"4b8dbba4f964a5201e0b33e3","categories":[{"id":18022,"name":"Boxing Gym","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/building/gym_","suffix":".png"}}],"chains":[],"distance":283,"geocodes":{"main":{"latitude":40.71321,"longitude":-74.008774},"roof":{"latitude":40.71321,"longitude":-74.008774}},"link":"/v3/places/4b8dbba4f964a5201e0b33e3","location":{"address":"25 Park Pl","address_extended":"Bsmt B","census_block":"360610021002001","country":"US","cross_street":"btwn Church St. & Broadway","dma":"New York","formatted_address":"25 Park Pl (btwn Church St. & Broadway), New York, NY 10007","locality":"New York","postcode":"10007","region":"NY"},"name":"Church Street Boxing Gym","related_places":{"parent":{"fsq_id":"503f5d1ee4b02a078d09051c","name":"25 Park Place"}},"timezone":"America/New_York"},{"fsq_id":"4e31888418380c94acabdd29","categories":[{"id":11026,"name":"Daycare","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/shops/daycare_","suffi
# ...

# %% [markdown]
# Put your parsed results into a DataFrame

# %%
# For all stations in "NEW YORK"
# Look at NEW YORK.json file in Data folder (GitHub)

client = citybikes.Client()
Cities = citybikes.Network(client, uid='citi-bike-nyc')

with open('NYC_stations.json', 'w') as f:
    json.dump(NYC_stations.data, f, indent=2)

# %% [markdown]
# # Yelp

# %% [markdown]
# Send a request to Yelp with a small radius (1000m) for all the bike stations in your city of choice.

# %%
import requests
import json

# Define a business ID
category_alias = 'citi-bike-nyc'

# Define API Key, Search Type, and header
MY_API_KEY = 'jCkFPFu4-UZGKVJE-3Ck_ESAt1GE2xEDAgFVIMS7rhIVRz3YZXYxPZK_rp5ZHKYvKHvnPujH2ESBQYLjJu7LeTuUMao1yPQUDbXDrnMq5BESmv7B16L2hIU7-rdJZHYx'
BUSINESS_PATH = 'https://api.yelp.com/v3/transactions/delivery/search'
HEADERS = {'Authorization': 'bearer %s' % MY_API_KEY}

# Define the Parameters of the search
PARAMETERS = {'location':'New York'}

# Make a Request to the API, and return results
response = requests.get(url=BUSINESS_PATH, 
                        params=PARAMETERS, 
                        headers=HEADERS)

# Convert response to a JSON String
business_data = response.json()  

# print the data
print(json.dumps(business_data, indent = 3))

# Define Parameters - Transaction Type
PARAMETERS = {'location':'New York'}

# Define Paramters -  Autocomplete
PARAMETERS = {'text': 'CityBikes',
              'latitude': 40.7143528,
              'longitude': -74.00597309999999,
              'limit': 100,
              'radius': 1000
             }
# Out:
# {
#    "businesses": [
#       {
#          "id": "DFFNe30NcyL1ZhDxos_yyA",
#          "alias": "bk-cafe-brooklyn",
#          "name": "BK Cafe",
#          "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/X1axkRJP0yjZdNfxuLrZ5g/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/bk-cafe-brooklyn?adjust_creative=nyzI_VHJj-t-_qVYe0AHfw&utm_campaign=yelp_api_v3&utm_medium=api_v3_transactions_search_delivery&utm_source=nyzI_VHJj-t-_qVYe0AHfw",
#          "review_count": 1,
#          "categories": [
#             {
#                "alias": "thai",
#                "title": "Thai"
#             }
#          ],
#          "rating": 5.0,
#          "coordinates": {
#             "latitude": 40.70177316341405,
#             "longitude": -73.9242596
#          },
#          "transactions": [
#             "delivery",
#             "pickup"
#          ],
#          "location": {
#             "address1": "247 Suydam St",
#             "address2": null,
# ...

# %% [markdown]
# Parse through the response to get the POI (such as restaurants, bars, etc) details you want (ratings, name, location, etc)

# %%
import requests
import json

# Define a business ID
category_alias = 'citi-bike-nyc'

# Define API Key, Search Type, and header
MY_API_KEY = 'jCkFPFu4-UZGKVJE-3Ck_ESAt1GE2xEDAgFVIMS7rhIVRz3YZXYxPZK_rp5ZHKYvKHvnPujH2ESBQYLjJu7LeTuUMao1yPQUDbXDrnMq5BESmv7B16L2hIU7-rdJZHYx'
BUSINESS_PATH = 'https://api.yelp.com/v3/transactions/delivery/search'
HEADERS = {'Authorization': 'bearer %s' % MY_API_KEY}

# Define the Parameters of the search
PARAMETERS = {'location':'New York'}

# Make a Request to the API, and return results
response = requests.get(url=BUSINESS_PATH, 
                        params=PARAMETERS, 
                        headers=HEADERS)

# Convert response to a JSON String
business_data = response.json()  

# print the data
print(json.dumps(business_data, indent = 3))

# Define Parameters - Transaction Type
PARAMETERS = {'location':'New York'}

# Define Paramters -  Autocomplete
PARAMETERS = {'text': 'Italian Resturants',
              'latitude': 40.7143528,
              'longitude': -74.00597309999999,
              'limit': 100,
              'radius': 1000
             }
# Out:
# {
#    "businesses": [
#       {
#          "id": "03icxNONL86QOeZQLsyrnA",
#          "alias": "semkeh-brooklyn",
#          "name": "Semkeh",
#          "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/tI0Ke72s8wWnpC3ssyrDkA/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/semkeh-brooklyn?adjust_creative=nyzI_VHJj-t-_qVYe0AHfw&utm_campaign=yelp_api_v3&utm_medium=api_v3_transactions_search_delivery&utm_source=nyzI_VHJj-t-_qVYe0AHfw",
#          "review_count": 45,
#          "categories": [
#             {
#                "alias": "lebanese",
#                "title": "Lebanese"
#             },
#             {
#                "alias": "falafel",
#                "title": "Falafel"
#             }
#          ],
#          "rating": 4.5,
#          "coordinates": {
#             "latitude": 40.7057062,
#             "longitude": -73.932148
#          },
#          "transactions": [
#             "delivery",
#             "pickup"
# ...

# %%
import requests
import json

# Define a business ID
category_alias = 'citi-bike-nyc'

# Define API Key, Search Type, and header
MY_API_KEY = 'jCkFPFu4-UZGKVJE-3Ck_ESAt1GE2xEDAgFVIMS7rhIVRz3YZXYxPZK_rp5ZHKYvKHvnPujH2ESBQYLjJu7LeTuUMao1yPQUDbXDrnMq5BESmv7B16L2hIU7-rdJZHYx'
BUSINESS_PATH = 'https://api.yelp.com/v3/transactions/delivery/search'
HEADERS = {'Authorization': 'bearer %s' % MY_API_KEY}

# Define the Parameters of the search
PARAMETERS = {'location':'New York'}

# Make a Request to the API, and return results
response = requests.get(url=BUSINESS_PATH, 
                        params=PARAMETERS, 
                        headers=HEADERS)

# Convert response to a JSON String
business_data = response.json()  

# print the data
print(json.dumps(business_data, indent = 3))

# Define Parameters - Transaction Type
PARAMETERS = {'location':'New York'}

# Define Paramters -  Autocomplete
PARAMETERS = {'text': 'bars',
              'latitude': 40.7143528,
              'longitude': -74.00597309999999,
              'limit': 100,
              'radius': 1000
             }
# Out:
# {
#    "businesses": [
#       {
#          "id": "03icxNONL86QOeZQLsyrnA",
#          "alias": "semkeh-brooklyn",
#          "name": "Semkeh",
#          "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/tI0Ke72s8wWnpC3ssyrDkA/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/semkeh-brooklyn?adjust_creative=nyzI_VHJj-t-_qVYe0AHfw&utm_campaign=yelp_api_v3&utm_medium=api_v3_transactions_search_delivery&utm_source=nyzI_VHJj-t-_qVYe0AHfw",
#          "review_count": 45,
#          "categories": [
#             {
#                "alias": "lebanese",
#                "title": "Lebanese"
#             },
#             {
#                "alias": "falafel",
#                "title": "Falafel"
#             }
#          ],
#          "rating": 4.5,
#          "coordinates": {
#             "latitude": 40.7057062,
#             "longitude": -73.932148
#          },
#          "transactions": [
#             "delivery",
#             "pickup"
# ...

# %%
import requests
import json

# Define a business ID
category_alias = 'citi-bike-nyc'

# Define API Key, Search Type, and header
MY_API_KEY = 'jCkFPFu4-UZGKVJE-3Ck_ESAt1GE2xEDAgFVIMS7rhIVRz3YZXYxPZK_rp5ZHKYvKHvnPujH2ESBQYLjJu7LeTuUMao1yPQUDbXDrnMq5BESmv7B16L2hIU7-rdJZHYx'
BUSINESS_PATH = 'https://api.yelp.com/v3/transactions/delivery/search'
HEADERS = {'Authorization': 'bearer %s' % MY_API_KEY}

# Define the Parameters of the search
PARAMETERS = {'location':'New York'}

# Make a Request to the API, and return results
response = requests.get(url=BUSINESS_PATH, 
                        params=PARAMETERS, 
                        headers=HEADERS)

# Convert response to a JSON String
business_data = response.json()  

# print the data
print(json.dumps(business_data, indent = 3))

# Define Parameters - Transaction Type
PARAMETERS = {'location':'New York'}

# Define Paramters -  Autocomplete
PARAMETERS = {'text': 'Schools',
              'latitude': 40.7143528,
              'longitude': -74.00597309999999,
              'limit': 100,
              'radius': 1000
             }
# Out:
# {
#    "businesses": [
#       {
#          "id": "03icxNONL86QOeZQLsyrnA",
#          "alias": "semkeh-brooklyn",
#          "name": "Semkeh",
#          "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/tI0Ke72s8wWnpC3ssyrDkA/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/semkeh-brooklyn?adjust_creative=nyzI_VHJj-t-_qVYe0AHfw&utm_campaign=yelp_api_v3&utm_medium=api_v3_transactions_search_delivery&utm_source=nyzI_VHJj-t-_qVYe0AHfw",
#          "review_count": 45,
#          "categories": [
#             {
#                "alias": "lebanese",
#                "title": "Lebanese"
#             },
#             {
#                "alias": "falafel",
#                "title": "Falafel"
#             }
#          ],
#          "rating": 4.5,
#          "coordinates": {
#             "latitude": 40.7057062,
#             "longitude": -73.932148
#          },
#          "transactions": [
#             "delivery",
#             "pickup"
# ...

# %%
import requests
import json

# Define a business ID
category_alias = 'citi-bike-nyc'

# Define API Key, Search Type, and header
MY_API_KEY = 'jCkFPFu4-UZGKVJE-3Ck_ESAt1GE2xEDAgFVIMS7rhIVRz3YZXYxPZK_rp5ZHKYvKHvnPujH2ESBQYLjJu7LeTuUMao1yPQUDbXDrnMq5BESmv7B16L2hIU7-rdJZHYx'
BUSINESS_PATH = 'https://api.yelp.com/v3/transactions/delivery/search'
HEADERS = {'Authorization': 'bearer %s' % MY_API_KEY}

# Define the Parameters of the search
PARAMETERS = {'location':'New York'}

# Make a Request to the API, and return results
response = requests.get(url=BUSINESS_PATH, 
                        params=PARAMETERS, 
                        headers=HEADERS)

# Convert response to a JSON String
business_data = response.json()  

# print the data
print(json.dumps(business_data, indent = 3))

# Define Parameters - Transaction Type
PARAMETERS = {'location':'New York'}

# Define Paramters -  Autocomplete
PARAMETERS = {'text': 'rating',
              'latitude': 40.7143528,
              'longitude': -74.00597309999999,
              'limit': 100,
              'radius': 1000
             }
# Out:
# {
#    "businesses": [
#       {
#          "id": "03icxNONL86QOeZQLsyrnA",
#          "alias": "semkeh-brooklyn",
#          "name": "Semkeh",
#          "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/tI0Ke72s8wWnpC3ssyrDkA/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/semkeh-brooklyn?adjust_creative=nyzI_VHJj-t-_qVYe0AHfw&utm_campaign=yelp_api_v3&utm_medium=api_v3_transactions_search_delivery&utm_source=nyzI_VHJj-t-_qVYe0AHfw",
#          "review_count": 45,
#          "categories": [
#             {
#                "alias": "lebanese",
#                "title": "Lebanese"
#             },
#             {
#                "alias": "falafel",
#                "title": "Falafel"
#             }
#          ],
#          "rating": 4.5,
#          "coordinates": {
#             "latitude": 40.7057062,
#             "longitude": -73.932148
#          },
#          "transactions": [
#             "delivery",
#             "pickup"
# ...

# %% [markdown]
# Put your parsed results into a DataFrame

# %%
import pandas as pd
df_YELPStations = pd.read_csv("B:/Week3/Project2/df_YELPStations.csv")
df_YELPStations.head()
# Out:
#            businesses__id    businesses__alias businesses__name  \
# 0  DFFNe30NcyL1ZhDxos_yyA     bk-cafe-brooklyn          BK Cafe
# 1  03icxNONL86QOeZQLsyrnA      semkeh-brooklyn           Semkeh
# 2                     NaN                  NaN              NaN
# 3  IuMvrvXTTZm4NQYO1O1dbg  kuma-nyc-brooklyn-2         Kuma NYC
# 4                     NaN                  NaN              NaN
#
#                                businesses__image_url businesses__is_closed  \
# 0  https://s3-media3.fl.yelpcdn.com/bphoto/X1axkR...                 False
# 1  https://s3-media4.fl.yelpcdn.com/bphoto/tI0Ke7...                 False
# 2                                                NaN                   NaN
# 3  https://s3-media1.fl.yelpcdn.com/bphoto/s5SvRV...                 False
# 4                                                NaN                   NaN
#
#                                      businesses__url  \
# 0  https://www.yelp.com/biz/bk-cafe-brooklyn?adju...
# ...

# %%
df_YELPStations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 27 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   businesses__id                              20 non-null     object
#  1   businesses__alias                           20 non-null     object
#  2   businesses__name                            20 non-null     object
#  3   businesses__image_url                       20 non-null     object
#  4   businesses__is_closed                       20 non-null     object
#  5   businesses__url                             20 non-null     object
#  6   businesses__review_count                    20 non-null     float64
#  7   businesses__categories__alias               33 non-null     object
#  8   businesses__categories__title               33 non-null     object
#  9   businesses__rating                          20 non-null     float64
# ...

# %%
df_YELPStations.shape
# Out:
# (33, 27)

# %%
df_YELPStations.describe()
# Out:
#        businesses__review_count  businesses__rating  \
# count                 20.000000           20.000000
# mean                 149.000000            3.750000
# std                  132.557832            0.638666
# min                    1.000000            2.500000
# 25%                   65.250000            3.375000
# 50%                  123.500000            4.000000
# 75%                  196.500000            4.000000
# max                  581.000000            5.000000
#
#        businesses__coordinates__latitude  businesses__coordinates__longitude  \
# count                          20.000000                           20.000000
# mean                           40.699715                          -73.919511
# std                             0.004830                            0.008233
# min                            40.684020                          -73.932148
# 25%                            40.698781                          -73.925621
# ...

# %% [markdown]
# # Comparing Results

# %% [markdown]
# Which API provided you with more complete data? Provide an explanation.

# %% [markdown]
# By comparing the data that colected from the two API of FOURSQURE AND YELP.
# I found the data that collectecd by YELP API is more accurate from foursqure api.
# the reason:
# Yelp is a business review website, though restaurants are where its database is the most complete. The Yelp API provides access to not only its listings, but also its reviews and photos, making it a great choice. Coverage is good in the U.S., but only a few select international cities have Yelp listings.
# ....
# Foursquare is used as a place database by many developers, but it's important to remember the service is geared toward check-ins. You can filter results by both name and category. Foursquare's database is user-generated, so it will be most complete where their user base is strongest. Also, it may be more likely to contain duplicates, but also has non-business listings. This may be parks, bus stops or even individual homes. Because it's based on check-ins, Foursquare has an option to sort by popularity or proximity.

# %% [markdown]
# Get the top 10 restaurants according to their rating

# %%
import requests
import json

# Define a business ID
category_alias = 'citi-bike-nyc'

# Define API Key, Search Type, and header
MY_API_KEY = 'jCkFPFu4-UZGKVJE-3Ck_ESAt1GE2xEDAgFVIMS7rhIVRz3YZXYxPZK_rp5ZHKYvKHvnPujH2ESBQYLjJu7LeTuUMao1yPQUDbXDrnMq5BESmv7B16L2hIU7-rdJZHYx'
BUSINESS_PATH = 'https://api.yelp.com/v3/transactions/delivery/search'
HEADERS = {'Authorization': 'bearer %s' % MY_API_KEY}

# Define the Parameters of the search
PARAMETERS = {'location':'New York'}

# Make a Request to the API, and return results
response = requests.get(url=BUSINESS_PATH, 
                        params=PARAMETERS, 
                        headers=HEADERS)

# Convert response to a JSON String
business_data = response.json()  

# print the data
print(json.dumps(business_data, indent = 3))

# Define Parameters - Transaction Type
PARAMETERS = {'location':'New York'}

# Define Paramters -  Autocomplete
PARAMETERS = {'text': 'rating',
              'latitude': 40.7143528,
              'longitude': -74.00597309999999,
              'limit': 10,
              'radius': 1000
             }
# Out:
# {
#    "businesses": [
#       {
#          "id": "NjDI7uiks5GO-GyeJ4L1zg",
#          "alias": "abracadabra-magic-deli-brooklyn",
#          "name": "Abracadabra Magic Deli",
#          "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/Tg5rqeS4Td7XWgbpjyoGXg/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/abracadabra-magic-deli-brooklyn?adjust_creative=nyzI_VHJj-t-_qVYe0AHfw&utm_campaign=yelp_api_v3&utm_medium=api_v3_transactions_search_delivery&utm_source=nyzI_VHJj-t-_qVYe0AHfw",
#          "review_count": 52,
#          "categories": [
#             {
#                "alias": "delis",
#                "title": "Delis"
#             },
#             {
#                "alias": "turkish",
#                "title": "Turkish"
#             }
#          ],
#          "rating": 4.5,
#          "coordinates": {
#             "latitude": 40.70359,
#             "longitude": -73.92727
#          },
#          "transactions": [
# ...

# %%
import pandas as pd
TopTenResturant = pd.read_csv("B:/Week3/Project2/TopTenResturant.csv")
TopTenResturant.head(11)
# Out:
#             businesses__id                 businesses__alias  \
# 0   NjDI7uiks5GO-GyeJ4L1zg   abracadabra-magic-deli-brooklyn
# 1                      NaN                               NaN
# 2   j_x5CbFjKfPcvakcWCE_hA            kings-kolache-brooklyn
# 3                      NaN                               NaN
# 4                      NaN                               NaN
# 5   -zzMDQkhZzrnBUdrfpG3Ng           ange-noir-cafe-brooklyn
# 6                      NaN                               NaN
# 7                      NaN                               NaN
# 8   4C9uO4dRUFW-QPLDfIqibA                  montazo-brooklyn
# 9   FGIXGWJ3ZV-wRbziBneGjw  merindas-deli-and-grill-brooklyn
# 10                     NaN                               NaN
#
#           businesses__name                              businesses__image_url  \
# 0   Abracadabra Magic Deli  https://s3-media1.fl.yelpcdn.com/bphoto/Tg5rqe...
# ...
